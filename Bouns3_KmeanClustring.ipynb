# %%
import matplotlib.pyplot as plt
x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]
n_clusters=2

result1=plt.scatter(x, y)
plt.title('The Data Repressentation Before clustring')
result1=plt.show(result1)

# %%
from sklearn.cluster import KMeans
def clustring(x,y,n_clusters):
    data = list(zip(x, y))
    kmeans = KMeans(n_clusters)
    kmeans.fit(data)
    result2=plt.scatter(x, y, c=kmeans.labels_)
    result2=plt.show()
    return result
#calling
plt.title('Clusterd Data')
clustring(x,y,n_clusters)
